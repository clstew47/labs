# %% [markdown]
# # Web Scraping
#
# Last time, we looked at REST API's as a source of data. You can get lots of very high quality data this way.
#
# Some data is available online, but not through an API. When this is the case, some times you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with.

# %% [markdown]
# We'll be scraping data about used cars in Charlottesville from Craigslist. This will give us a chance to put those wrangling, EDA, and visualization skills to work.
#
# We'll use the `requests` package, as we did with API's, but will be getting the kinds of web pages you see everyday. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0'
raw = requests.get(url,headers=header) # Get page

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tages, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.

# %% [markdown]
# ## 1. Pick something else on Craigslist: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of EDA you'd do with it.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# For each listing, we'll use the `.find` method to search within the listing record for specific information. To get the information we want, we can then use `.get_text()`.
#
# In the code below, two more things happen.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %% [markdown]
# ## 2. Get your search results of interest and extract data from them, using code similar to what's above.

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (90, 6)
#                                 title  price    year  \
# 0     2017 nissan sentra sr turbo cvt  14000  2017.0
# 1           1997 bmw 328i convertible   4600  1997.0
# 2        1974 dodge stepside 426 hemi  10500  1974.0
# 3  2013 lexus rx350 only 61,500 miles  18900  2013.0
# 4                        sequoia 2005   2000  2005.0
#
#                                                 link    brand   age
# 0  https://charlottesville.craigslist.org/cto/d/c...  missing   8.0
# 1  https://charlottesville.craigslist.org/cto/d/c...      bmw  28.0
# 2  https://charlottesville.craigslist.org/cto/d/l...    dodge  51.0
# 3  https://charlottesville.craigslist.org/cto/d/m...    lexus  12.0
# 4  https://charlottesville.craigslist.org/cto/d/c...  missing  20.0

# %% [markdown]
# With the data in and wrangled, we can now do EDA:

# %%
# EDA for price and age:
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count       90.000000
# mean      8228.588889
# std       7998.559398
# min         10.000000
# 25%       3000.000000
# 50%       5900.000000
# 75%      10975.000000
# max      49900.000000
# Name: price, dtype: float64
# count    74.000000
# mean     18.959459
# std      10.918677
# min       4.000000
# 25%      12.000000
# 50%      18.000000
# 75%      21.000000
# max      63.000000
# Name: age, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#            price                                                          \
#            count          mean           std      min       25%      50%
# brand
# acura        1.0   3500.000000           NaN   3500.0   3500.00   3500.0
# audi         2.0   6432.500000   7399.872465   1200.0   3816.25   6432.5
# bmw          5.0   5600.000000   2026.079959   3000.0   4600.00   5900.0
# buick        3.0   3700.000000    984.885780   2600.0   3300.00   4000.0
# chevrolet    3.0  10000.000000   6500.000000   6000.0   6250.00   6500.0
# chevy        4.0   4002.500000   3261.905118     10.0   3002.50   4000.0
# dodge        5.0   6900.000000   3471.310992   2000.0   6000.00   6000.0
# ford         7.0   6278.571429   4321.829970   1000.0   2500.00   7250.0
# gmc          3.0   8300.000000   5980.802622   3500.0   4950.00   6400.0
# honda       10.0   7144.900000   3926.982739   1000.0   4725.00   7200.0
# jeep         4.0   8725.000000   7818.940678   1500.0   2625.00   7750.0
# kia          1.0   9500.000000           NaN   9500.0   9500.00   9500.0
# lexus        2.0  16925.000000   2793.071786  14950.0  15937.50  16925.0
# missing     23.0   8997.782609   8545.941057   1200.0   2900.00   4950.0
# mitsubishi   1.0   2500.000000           NaN   2500.0   2500.00   2500.0
# subaru       3.0   4300.000000   2787.471973   2000.0   2750.00   3500.0
# tesla        2.0  21450.000000   6434.671709  16900.0  19175.00  21450.0
# toyota       9.0  12650.000000  16599.359927   1500.0   3300.00   4100.0
# volkswagen   1.0   4950.000000           NaN   4950.0   4950.00   4950.0
# volvo        1.0   2000.000000           NaN   2000.0   2000.00   2000.0
#
#
#                  75%      max
# brand
# acura        3500.00   3500.0
# audi         9048.75  11665.0
# bmw          6000.00   8500.0
# buick        4250.00   4500.0
# chevrolet   12000.00  17500.0
# chevy        5000.00   8000.0
# dodge       10000.00  10500.0
# ford         9600.00  11500.0
# gmc         10700.00  15000.0
# honda        9637.50  13000.0
# jeep        13850.00  17900.0
# kia          9500.00   9500.0
# lexus       17912.50  18900.0
# missing     14500.00  31950.0
# mitsubishi   2500.00   2500.0
# subaru       5450.00   7400.0
# tesla       23725.00  26000.0
# toyota      11000.00  49900.0
# volkswagen   4950.00   4950.0
# volvo        2000.00   2000.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#              age
#            count       mean        std   min    25%   50%    75%   max
# brand
# acura        1.0  17.000000        NaN  17.0  17.00  17.0  17.00  17.0
# audi         1.0  21.000000        NaN  21.0  21.00  21.0  21.00  21.0
# bmw          3.0  17.666667   9.073772  11.0  12.50  14.0  21.00  28.0
# buick        1.0  19.000000        NaN  19.0  19.00  19.0  19.00  19.0
# chevrolet    3.0  27.333333   9.609024  17.0  23.00  29.0  32.50  36.0
# chevy        3.0  26.333333   4.163332  23.0  24.00  25.0  28.00  31.0
# dodge        2.0  36.000000  21.213203  21.0  28.50  36.0  43.50  51.0
# ford         6.0  21.833333   9.152413  13.0  17.25  19.0  23.00  39.0
# gmc          3.0  16.000000   9.539392  10.0  10.50  11.0  19.00  27.0
# honda       10.0  17.000000   7.180220  10.0  11.25  15.5  20.50  33.0
# jeep         3.0  37.333333  22.368132  22.0  24.50  27.0  45.00  63.0
# kia          1.0   9.000000        NaN   9.0   9.00   9.0   9.00   9.0
# lexus        2.0  13.500000   2.121320  12.0  12.75  13.5  14.25  15.0
# missing     19.0  17.210526  11.905083   6.0  11.50  16.0  19.50  62.0
# mitsubishi   1.0  19.000000        NaN  19.0  19.00  19.0  19.00  19.0
# subaru       3.0  16.000000   2.645751  13.0  15.00  17.0  17.50  18.0
# tesla        2.0   8.000000   1.414214   7.0   7.50   8.0   8.50   9.0
# toyota       8.0  14.625000   8.314145   4.0   7.00  15.0  20.50  27.0
# volkswagen   1.0  15.000000        NaN  15.0  15.00  15.0  15.00  15.0
# volvo        1.0  21.000000        NaN  21.0  21.00  21.0  21.00  21.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   1.171789 -0.236318
# log_age    -0.236318  0.269238
#            log_price   log_age
# log_price   1.000000 -0.502135
# log_age    -0.502135  1.000000

# %%
sns.jointplot(data=df, x='log_age', y='log_price',kind='hex')

# %% [markdown]
# ## 3. Wrangle your data, do some EDA, and make some plots. Try to find some interesting relationships or stories to tell about your data.

# %% [markdown]
# The final thing we want to do is go from scraping a single page to crawling around.
#
# The idea here is that every web page is connected to some other page. By extracting links as we move from page to page, we can create a web crawler that wanders around for us, gathering information of interest.
#
# In this case, we want to use the search results to then visit each individual page for each listing. Since we saved the links to the web pages in the previous scrape, we can now simply for-loop over that column in the dataframe, visiting the page listing for each of the cars in the search results:

# %%
import time # Time delays
import random # Random numbers

links = df['link']
data = []
for link in links: # about 3 minutes
    time.sleep(random.randint(1, 3)) # Random delays
    raw = requests.get(link,headers=header) # Get page
    bsObj = soup(raw.content,'html.parser') # Parse the html
    #
    try:
        year_post = bsObj.find(class_='attr important').find(class_ = 'valu year').get_text()
    except:
        year_post = np.nan
    #
    try:
        condition = bsObj.find(class_='attr condition').find(href=True).get_text()
    except:
        condition = 'missing'
    #
    try:
        cylinders = bsObj.find(class_='attr auto_cylinders').find(class_ = 'valu').get_text()
        cylinders = cylinders.replace('\n','')
    except:
        cylinders = 'missing'
    #
    try:
        drivetrain = bsObj.find(class_='attr auto_drivetrain').find(href=True).get_text()
    except:
        drivetrain = 'missing'
    #
    try:
        fuel = bsObj.find(class_='attr auto_fuel_type').find(href = True).get_text()
    except:
        fuel = 'missing'
    #
    try:
        miles = bsObj.find(class_='attr auto_miles').find(class_ = 'valu').get_text()
    except:
        miles = np.nan
    #
    try:
        color = bsObj.find(class_='attr auto_paint').find(href=True).get_text()
    except:
        color='missing'
    #
    try:
        title = bsObj.find(class_='attr auto_title_status').find(href=True).get_text()
    except:
        title='missing'
    #
    try:
        transmission = bsObj.find(class_='attr auto_transmission').find(href=True).get_text()
    except:
        transmission = 'missing'
    #
    try:
        bodytype = bsObj.find(class_='attr auto_bodytype').find(href=True).get_text()
    except:
        bodytype = 'missing'
    #
    text = bsObj.find(id='postingbody').get_text()
    text = text.replace('\n','')
    text = text.replace('QR Code Link to This Post','')
    record = {'title':title,
              'year_post':year_post,
              'condition':condition,
              'cylinders':cylinders,
              'drivetrain':drivetrain,
              'fuel':fuel,
              'miles':miles,
              'color':color,
              'title':'title',
              'transmission':transmission,
              'bodytype':bodytype,
              'text':text,}
    data.append(record)

# %% [markdown]
# What are the new features here?
#
# First, we don't want to overwhelm the servers, so we put a small delay between each request of a listing, `time.sleep(random.randint(1, 3))`. This waits a random amount of time between 1 and 3 seconds to avoid overwhelming their server.
#
# Second, we use the try/except block. This is a useful control structure in general, but especially for web scraping. Python tries the statements under `try:`, and if it fails, executes the steps under `except:`. This can happen, in this case, with missing data, which crashes the crawler. Instead, we put our missing codes into our dataframe right away.
#
# Third, we used `.find().find().get_text()` to find the data we're looking for. In general, the structure of mark-up langauges like HTML and XML makes it possible to "drill down" into their entries and extract the information of interest. This exploitation of mark-up languages could be the subject of a whole course on procuring data from the web.

# %%
new_df = pd.DataFrame.from_dict(data)
new_df.head()
# Out:
#    title year_post  condition     cylinders drivetrain fuel    miles   color  \
# 0  title      2017  excellent   4 cylinders    missing  gas   95,000    grey
# 1  title      1997  excellent   6 cylinders        rwd  gas  161,645   black
# 2  title      1974  excellent   8 cylinders        rwd  gas   68,000  yellow
# 3  title      2013  excellent   6 cylinders        4wd  gas   61,500   white
# 4  title      2005       good   8 cylinders        4wd  gas  240,000   black
#
#   transmission     bodytype                                               text
# 0    automatic        sedan  This 2017 Nissan Sentra offers a unique blend ...
# 1    automatic  convertible  Clean title in hand - Lots of pictures!-Extrem...
# 2    automatic        truck  Mopar Guys!!!!  Must see this super rare Mopar...
# 3    automatic          SUV  One owner 2013 Lexus RX350. Driven by my wife,...
# 4    automatic      missing  240k highway miles, Runs well, cold ac. Only i...

# %% [markdown]
# With the data scraped, we can make a new dataframe, combine it with the old one using `pd.concat`, and do some wrangling to clean the data up:

# %%
new_df.shape
# Out:
# (90, 11)

# %%
df = pd.concat([df,new_df],axis=1) # combine data frames
df.head()
# Out:
#                                 title  price    year  \
# 0     2017 nissan sentra sr turbo cvt  14000  2017.0
# 1           1997 bmw 328i convertible   4600  1997.0
# 2        1974 dodge stepside 426 hemi  10500  1974.0
# 3  2013 lexus rx350 only 61,500 miles  18900  2013.0
# 4                        sequoia 2005   2000  2005.0
#
#                                                 link    brand   age  \
# 0  https://charlottesville.craigslist.org/cto/d/c...  missing   8.0
# 1  https://charlottesville.craigslist.org/cto/d/c...      bmw  28.0
# 2  https://charlottesville.craigslist.org/cto/d/l...    dodge  51.0
# 3  https://charlottesville.craigslist.org/cto/d/m...    lexus  12.0
# 4  https://charlottesville.craigslist.org/cto/d/c...  missing  20.0
#
#    log_price   log_age  title year_post  condition     cylinders drivetrain  \
# 0   9.546813  2.079442  title      2017  excellent   4 cylinders    missing
# 1   8.433812  3.332205  title      1997  excellent   6 cylinders        rwd
# 2   9.259131  3.931826  title      1974  excellent   8 cylinders        rwd
# 3   9.846917  2.484907  title      2013  excellent   6 cylinders        4wd
# 4   7.600902  2.995732  title      2005       good   8 cylinders        4wd
#
#   fuel    miles   color transmission     bodytype  \
# 0  gas   95,000    grey    automatic        sedan
# 1  gas  161,645   black    automatic  convertible
# 2  gas   68,000  yellow    automatic        truck
# 3  gas   61,500   white    automatic          SUV
# 4  gas  240,000   black    automatic      missing
#
#                                                 text
# 0  This 2017 Nissan Sentra offers a unique blend ...
# 1  Clean title in hand - Lots of pictures!-Extrem...
# 2  Mopar Guys!!!!  Must see this super rare Mopar...
# 3  One owner 2013 Lexus RX350. Driven by my wife,...
# 4  240k highway miles, Runs well, cold ac. Only i...

# %%
df['miles'] = df['miles'].str.replace(',', '')
df['miles'] = pd.to_numeric(df['miles'], errors='coerce')

# %%
df['year_post'] = df['year_post'].str.replace(',','')
df['year_post'] = pd.to_numeric(df['year_post'],errors='coerce')
df.to_csv('craiglist_cville_cars_long.csv')

# %%
# Re-doing lab on "Bikes" search
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/bia#search=1~gallery~0~0'
raw = requests.get(url,headers=header) # Get page

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings
# Out:
# [<li class="cl-static-search-result" title="2021 Giant Anthem Advanced Pro 29 0, Size Large">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-2021-giant-anthem/7789940222.html">
# <div class="title">2021 Giant Anthem Advanced Pro 29 0, Size Large</div>
# <div class="details">
# <div class="price">$4,000</div>
# <div class="location">
#                         Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="2021 Giant XTC Advanced 29 0, Size Large">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-2021-giant-xtc-advanced/7789938928.html">
# <div class="title">2021 Giant XTC Advanced 29 0, Size Large</div>
# <div class="details">
# <div class="price">$3,500</div>
# <div class="location">
#                         Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Pedego Interceptor E-Bike">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-pedego-interceptor-bike/7789786487.html">
# <div class="title">Pedego Interceptor E-Bike</div>
# <div class="details">
# <div class="price">$1,400</div>
# <div class="location">
#                         Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Trek Wasabi Alpha Custom Single Speed Pink Women’s 17” Frame Cruiser B">
# <a href="https://charlottesville.craigslist.org/bik/d/north-garden-trek-wasabi-alpha-custom/7789054819.html">
# <div class="title">Trek Wasabi Alpha Custom Single Speed Pink Women’s 17” Frame Cruiser B</div>
# <div class="details">
# <div class="price">$300</div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Bicycles">
# <a href="https://charlottesville.craigslist.org/bik/d/batesville-bicycles/7789591658.html">
# <div class="title">Bicycles</div>
# <div class="details">
# <div class="price">$30</div>
# <div class="location">
#                         Batesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="VINTAGE SCHWINN CHILDS BIKE">
# <a href="https://charlottesville.craigslist.org/bik/d/dyke-vintage-schwinn-childs-bike/7782884453.html">
# <div class="title">VINTAGE SCHWINN CHILDS BIKE</div>
# <div class="details">
# <div class="price">$75</div>
# <div class="location">
#                         Dyke/Nortonsville Va
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Unisex bicycle">
# <a href="https://charlottesville.craigslist.org/bik/d/palmyra-unisex-bicycle/7781026024.html">
# <div class="title">Unisex bicycle</div>
# <div class="details">
# <div class="price">$55</div>
# <div class="location">
#                         Palmyra
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Trek Shift 1 Bicycle bike">
# <a href="https://charlottesville.craigslist.org/bik/d/afton-trek-shift-bicycle-bike/7789457963.html">
# <div class="title">Trek Shift 1 Bicycle bike</div>
# <div class="details">
# <div class="price">$180</div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Colnago EPS, Campy Super Record, Zipp303wheels, 56 size">
# <a href="https://charlottesville.craigslist.org/bik/d/henrico-colnago-eps-campy-super-record/7782576163.html">
# <div class="title">Colnago EPS, Campy Super Record, Zipp303wheels, 56 size</div>
# <div class="details">
# <div class="price">$2,250</div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="GT Bikes Stomper Kids/Child Bicycle">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-gt-bikes-stomper-kids/7783612454.html">
# <div class="title">GT Bikes Stomper Kids/Child Bicycle</div>
# <div class="details">
# <div class="price">$60</div>
# <div class="location">
#                         Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="E-Bike for Sale">
# <a href="https://charlottesville.craigslist.org/bik/d/scottsville-bike-for-sale/7788589227.html">
# <div class="title">E-Bike for Sale</div>
# <div class="details">
# <div class="price">$850</div>
# <div class="location">
#                         Scottsville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="2005 Cannondale CAAD5 R600 road bike">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-2005-cannondale-caad5/7788583772.html">
# <div class="title">2005 Cannondale CAAD5 R600 road bike</div>
# <div class="details">
# <div class="price">$400</div>
# <div class="location">
#                         Keswick/Pantops
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="** Price Reduced ** Talaria Sting electric dirt bike">
# <a href="https://charlottesville.craigslist.org/bik/d/buena-vista-price-reduced-talaria-sting/7780805425.html">
# <div class="title">** Price Reduced ** Talaria Sting electric dirt bike</div>
# <div class="details">
# <div class="price">$3,800</div>
# <div class="location">
#                         Lexington
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Santa Cruz tallboy carbon- large">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-santa-cruz-tallboy/7787905502.html">
# <div class="title">Santa Cruz tallboy carbon- large</div>
# <div class="details">
# <div class="price">$3,000</div>
# <div class="location">
#                         Belmont
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Schwinn">
# <a href="https://charlottesville.craigslist.org/bik/d/barboursville-schwinn/7787801030.html">
# <div class="title">Schwinn</div>
# <div class="details">
# <div class="price">$25</div>
# <div class="location">
#                         Barboursville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="2022 Turbo Creo SL Comp Carbon EVO">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-2022-turbo-creo-sl-comp/7786246408.html">
# <div class="title">2022 Turbo Creo SL Comp Carbon EVO</div>
# <div class="details">
# <div class="price">$4,500</div>
# <div class="location">
#                         Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="2024 Surly Karate Monkey">
# <a href="https://charlottesville.craigslist.org/bik/d/waynesboro-2024-surly-karate-monkey/7785927091.html">
# <div class="title">2024 Surly Karate Monkey</div>
# <div class="details">
# <div class="price">$1,700</div>
# <div class="location">
#                         Waynesboro
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Bicycle">
# <a href="https://charlottesville.craigslist.org/bik/d/nellysford-bicycle/7785740195.html">
# <div class="title">Bicycle</div>
# <div class="details">
# <div class="price">$85</div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="1993 Specialized Rockhopper Comp MTB">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-1993-specialized/7785676402.html">
# <div class="title">1993 Specialized Rockhopper Comp MTB</div>
# <div class="details">
# <div class="price">$475</div>
# <div class="location">
#                         Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Cheap Used Mountain Bike">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-cheap-used-mountain-bike/7784785040.html">
# <div class="title">Cheap Used Mountain Bike</div>
# <div class="details">
# <div class="price">$75</div>
# <div class="location">
#                         Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Woman/girls bicycle">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-woman-girls-bicycle/7784749265.html">
# <div class="title">Woman/girls bicycle</div>
# <div class="details">
# <div class="price">$55</div>
# <div class="location">
#                         Albemarle/Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="2023 Stumpjumper Carbon Frameset">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-2023-stumpjumper-carbon/7783989344.html">
# <div class="title">2023 Stumpjumper Carbon Frameset</div>
# <div class="details">
# <div class="price">$1,300</div>
# <div class="location">
#                         Charlottesville - Zion Crossroads
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Framed Minnesota Fat Tire Bike (sm/med women's) - $800 (charlottesvill">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-framed-minnesota-fat/7783063830.html">
# <div class="title">Framed Minnesota Fat Tire Bike (sm/med women's) - $800 (charlottesvill</div>
# <div class="details">
# <div class="price">$800</div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Garneau Gros Louis 2 Fat Tire Bike - $1200">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-garneau-gros-louis-fat/7783063795.html">
# <div class="title">Garneau Gros Louis 2 Fat Tire Bike - $1200</div>
# <div class="details">
# <div class="price">$1,200</div>
# <div class="location">
#                         charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Surly Ice Cream Truck Fat Tire Bike - $1,500 (Fayetteville)">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-surly-ice-cream-truck/7783063744.html">
# <div class="title">Surly Ice Cream Truck Fat Tire Bike - $1,500 (Fayetteville)</div>
# <div class="details">
# <div class="price">$1,500</div>
# <div class="location">
#                         charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Aventon Level .2">
# <a href="https://charlottesville.craigslist.org/bik/d/staunton-aventon-level/7782617595.html">
# <div class="title">Aventon Level .2</div>
# <div class="details">
# <div class="price">$1,100</div>
# <div class="location">
#                         Staunton
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="MOUNTAIN BIKE WITH GASOLINE MOTOR">
# <a href="https://charlottesville.craigslist.org/bik/d/troy-mountain-bike-with-gasoline-motor/7782290246.html">
# <div class="title">MOUNTAIN BIKE WITH GASOLINE MOTOR</div>
# <div class="details">
# <div class="price">$250</div>
# <div class="location">
#                         Troy
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="2019 Specialized Roubaix - 54cm - Full ultegra">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-2019-specialized/7782197710.html">
# <div class="title">2019 Specialized Roubaix - 54cm - Full ultegra</div>
# <div class="details">
# <div class="price">$1,965</div>
# <div class="location">
#                         Charlottesville Ivy
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Vintage bicycles">
# <a href="https://charlottesville.craigslist.org/bik/d/elkton-vintage-bicycles/7782071271.html">
# <div class="title">Vintage bicycles</div>
# <div class="details">
# <div class="price">$100</div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Gary Fisher">
# <a href="https://charlottesville.craigslist.org/bik/d/woodberry-forest-gary-fisher/7781133141.html">
# <div class="title">Gary Fisher</div>
# <div class="details">
# <div class="price">$140</div>
# <div class="location">
#                         Orange
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="GT Aggressor 24 youth mountain bike">
# <a href="https://charlottesville.craigslist.org/bik/d/crozet-gt-aggressor-24-youth-mountain/7780826114.html">
# <div class="title">GT Aggressor 24 youth mountain bike</div>
# <div class="details">
# <div class="price">$50</div>
# <div class="location">
#                         Crozet
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="StumpJumper Mountain Bike">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-stumpjumper-mountain/7780707695.html">
# <div class="title">StumpJumper Mountain Bike</div>
# <div class="details">
# <div class="price">$2,850</div>
# <div class="location">
#                         UVA/Huntington Village
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Kids bike">
# <a href="https://charlottesville.craigslist.org/bik/d/afton-kids-bike/7780414614.html">
# <div class="title">Kids bike</div>
# <div class="details">
# <div class="price">$50</div>
# <div class="location">
#                         Nelson County
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Norco Samurai">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-norco-samurai/7779938758.html">
# <div class="title">Norco Samurai</div>
# <div class="details">
# <div class="price">$150</div>
# <div class="location">
#                         Charlottesville
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Giant Trance (2023)">
# <a href="https://charlottesville.craigslist.org/bik/d/palmyra-giant-trance-2023/7779534238.html">
# <div class="title">Giant Trance (2023)</div>
# <div class="details">
# <div class="price">$2,000</div>
# <div class="location">
#                         Palmyra
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Giant XTC Hardtail Mountain Bike">
# <a href="https://charlottesville.craigslist.org/bik/d/palmyra-giant-xtc-hardtail-mountain-bike/7779529241.html">
# <div class="title">Giant XTC Hardtail Mountain Bike</div>
# <div class="details">
# <div class="price">$250</div>
# <div class="location">
#                         Palmyra
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Commencal meta ht 20inch wheels">
# <a href="https://charlottesville.craigslist.org/bik/d/charlottesville-commencal-meta-ht/7778753393.html">
# <div class="title">Commencal meta ht 20inch wheels</div>
# <div class="details">
# <div class="price">$400</div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="PRICE DROP-Colnago EPS, Campy Super Record, Zipp303wheels, 52s/56 size">
# <a href="https://charlottesville.craigslist.org/bik/d/henrico-price-drop-colnago-eps-campy/7771979809.html">
# <div class="title">PRICE DROP-Colnago EPS, Campy Super Record, Zipp303wheels, 52s/56 size</div>
# <div class="details">
# <div class="price">$2,500</div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title='Sun Electric Trike 24"'>
# <a href="https://charlottesville.craigslist.org/bik/d/covington-sun-electric-trike-24/7777912115.html">
# <div class="title">Sun Electric Trike 24"</div>
# <div class="details">
# <div class="price">$700</div>
# <div class="location">
#                         Covington
#                     </div>
# </div>
# </a>
# </li>, <li class="cl-static-search-result" title="Flight line FL26">
# <a href="https://charlottesville.craigslist.org/bik/d/palmyra-flight-line-fl26/7776726846.html">
# <div class="title">Flight line FL26</div>
# <div class="details">
# <div class="price">$450</div>
# <div class="location">
#                         Palmyra, va
#                     </div>
# </div>
# </a>
# </li>]

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %%
import re # Regular expressions

brands = ['bmx', 'cruiser', 'cyclocross', 'folding', 'gravel', 'hybrid/comfort', 'kids',
          'mountain', 'recumbent/trike', 'road', 'tandem', 'track', 'unicycle']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('craigslist_cville_bikes.csv') # Save data in case of a disaster
df.head()
# Out:
# (40, 6)
#                                                title  price    year  \
# 0    2021 giant anthem advanced pro 29 0, size large   4000  2021.0
# 1           2021 giant xtc advanced 29 0, size large   3500  2021.0
# 2                          pedego interceptor e-bike   1400     NaN
# 3  trek wasabi alpha custom single speed pink wom...    300     NaN
# 4                                           bicycles     30     NaN
#
#                                                 link    brand  age
# 0  https://charlottesville.craigslist.org/bik/d/c...  missing  4.0
# 1  https://charlottesville.craigslist.org/bik/d/c...  missing  4.0
# 2  https://charlottesville.craigslist.org/bik/d/c...  missing  NaN
# 3  https://charlottesville.craigslist.org/bik/d/n...  cruiser  NaN
# 4  https://charlottesville.craigslist.org/bik/d/b...  missing  NaN

# %%
# EDA for price and age:
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count      40.000000
# mean     1114.250000
# std      1280.513494
# min        25.000000
# 25%        96.250000
# 50%       462.500000
# 75%      1766.250000
# max      4500.000000
# Name: price, dtype: float64
# count     9.000000
# mean      8.222222
# std      10.615764
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max      32.000000
# Name: age, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#          price
#          count        mean          std    min    25%    50%      75%     max
# brand
# cruiser    1.0   300.00000          NaN  300.0  300.0  300.0   300.00   300.0
# kids       1.0    50.00000          NaN   50.0   50.0   50.0    50.00    50.0
# missing   32.0  1260.78125  1322.712944   25.0  130.0  825.0  1973.75  4500.0
# mountain   5.0   695.00000  1208.356322   50.0   75.0  250.0   250.00  2850.0
# road       1.0   400.00000          NaN  400.0  400.0  400.0   400.00   400.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#            age
#          count   mean        std   min   25%   50%   75%   max
# brand
# cruiser    0.0    NaN        NaN   NaN   NaN   NaN   NaN   NaN
# kids       0.0    NaN        NaN   NaN   NaN   NaN   NaN   NaN
# missing    8.0   6.75  10.319884   1.0   2.0   3.5   4.5  32.0
# mountain   0.0    NaN        NaN   NaN   NaN   NaN   NaN   NaN
# road       1.0  20.00        NaN  20.0  20.0  20.0  20.0  20.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   2.514468 -0.639131
# log_age    -0.639131  1.240680
#            log_price   log_age
# log_price   1.000000 -0.660474
# log_age    -0.660474  1.000000

# %%
sns.jointplot(data=df, x='log_age', y='log_price',kind='hex')

# %%
import time  # Time delays
import random  # Random numbers
import requests  # To fetch the page content
from bs4 import BeautifulSoup as soup  # For HTML parsing
import numpy as np  # For handling missing data

links = df['link']  # Assuming you have the links in a DataFrame
data = []
for link in links:  # Iterating over links
    time.sleep(random.randint(1, 3))  # Random delays between requests
    raw = requests.get(link, headers=header)  # Fetching the page
    bsObj = soup(raw.content, 'html.parser')  # Parsing the HTML

    try:
        bicycle_type = bsObj.find(class_='attr bicycle_type').find(class_='value').get_text()
    except:
        bicycle_type = 'missing'

    try:
        frame_size = bsObj.find(class_='attr frame_size').find(class_='value').get_text()
    except:
        frame_size = 'missing'

    try:
        wheel_size = bsObj.find(class_='attr wheel_size').find(class_='value').get_text()
    except:
        wheel_size = 'missing'

    try:
        frame_material = bsObj.find(class_='attr bicycle_frame_material').find(class_='value').get_text()
    except:
        frame_material = 'missing'

    try:
        condition = bsObj.find(class_='attr condition').find(href=True).get_text()
    except:
        condition = 'missing'

    try:
        manufacturer = bsObj.find(class_='attr make').find(class_='value').get_text()
    except:
        manufacturer = 'missing'

    try:
        model = bsObj.find(class_='attr model').find(class_='value').get_text()
    except:
        model = 'missing'

    # Scraping the description text
    try:
        text = bsObj.find(id='postingbody').get_text()
        text = text.replace('\n', '')
        text = text.replace('QR Code Link to This Post', '')
    except:
        text = 'missing'

    # Creating the record dictionary
    record = {
        'bicycle_type': bicycle_type,
        'frame_size': frame_size,
        'wheel_size': wheel_size,
        'frame_material': frame_material,
        'condition': condition,
        'manufacturer': manufacturer,
        'model': model,
        'text': text,
    }

    data.append(record)  # Appending the record to data

# %%
new_df = pd.DataFrame.from_dict(data)
new_df.head()
# Out:
#   bicycle_type frame_size wheel_size frame_material  condition manufacturer  \
# 0      missing    missing    missing        missing  excellent      missing
# 1      missing    missing    missing        missing  excellent      missing
# 2      missing    missing    missing        missing   like new      missing
# 3      missing    missing    missing        missing    missing      missing
# 4      missing    missing    missing        missing    missing      missing
#
#      model                                               text
# 0  missing  Make me an offer!This is a Size Large Anthem A...
# 1  missing  This is a Size Large XTC Advanced Pro 29 team ...
# 2  missing  Better than new! Extra clean in perfect condit...
# 3  missing  Trek Wasabi Alpha Custom Single Speed Pink Wom...
# 4  missing                 Have 2 bicycles for sale $30-EACH.

# %%
new_df.shape
# Out:
# (40, 8)

# %%
df = pd.concat([df,new_df],axis=1) # combine data frames
df.head()

df.to_csv('craiglist_cville_bikes_long.csv') # save to CSV
